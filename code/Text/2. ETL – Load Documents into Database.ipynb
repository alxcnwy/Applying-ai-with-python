# %% [markdown]
# # Text - Load Documents into Database

# %% [markdown]
# This notebook implements ETL - Extract, Transform, Load - to get our documents into a sqlite database

# %% [markdown]
# # Imports

# %%
import pandas as pd
from github import Github
import requests
from datetime import datetime, timezone
import json
import os
import re
import json
import csv
from github import GithubException
from requests.exceptions import RetryError
from urllib3.exceptions import MaxRetryError
from retrying import retry
import sqlite3
import pandas as pd

# %% [markdown]
# # Extract - Load the data

# %%
# Load the CSV file into a pandas DataFrame
file_path = 'data/combined.csv'
df = pd.read_csv(file_path)

# %%
# Display the first few rows of the DataFrame to verify the data
df.head(3).T
# Out:
#                                                                      0  \
# Talk ID                                                              1
# Title                                          Applying AI with Python
# Abstract             Artificial Intelligence (AI) is transforming i...
# Speaker Name                                               Alex Conway
# Speaker Profile URL           https://2024.za.pycon.org/users/alxcnwy/
# Talk URL             https://2024.za.pycon.org/talks/11-applying-ai...
# Speaker ID                                                           1
# Speaker ID.1                                                         1
# Name                                                       Alex Conway
# Profile URL                   https://2024.za.pycon.org/users/alxcnwy/
# Photo URL                                           No photo available
# Twitter                                    https://twitter.com/alxcnwy
# GitHub                                      https://github.com/alxcnwy
# Fediverse                                                          NaN
# Bio Part 1            Twitter Profile link:https://twitter.com/alxcnwy
# Bio Part 2           Other Social:https://www.linkedin.com/in/alxcnwy/
# Bio Part 3                   github profile:https://github.com/alxcnwy
#
#                                                                      1  \
# Talk ID                                                              2
# Title                Harnessing the Power of Community: Lessons fro...
# Abstract             Speedrunning, the art of completing video game...
# Speaker Name                                            Nunudzai Mrewa
# Speaker Profile URL         https://2024.za.pycon.org/users/JustNunuz/
# Talk URL             https://2024.za.pycon.org/talks/13-harnessing-...
# Speaker ID                                                           2
# Speaker ID.1                                                         2
# Name                                                    Nunudzai Mrewa
# Profile URL                 https://2024.za.pycon.org/users/JustNunuz/
# Photo URL                                           No photo available
# Twitter                                                            NaN
# GitHub                                    https://github.com/JustNunuz
# Fediverse                                                          NaN
# Bio Part 1           Twitter Profile link:https://x.com/_absolute_z3r0
# Bio Part 2             Other Social:https://www.linkedin.com/in/nunuz/
# Bio Part 3                 github profile:https://github.com/JustNunuz
#
#                                                                      2
# Talk ID                                                              3
# Title                It’s About Time: Time-Series Forecasting with ...
# Abstract             Along with the rise of “AI”, data-driven decis...
# Speaker Name                                            Brenden Taylor
# Speaker Profile URL  https://2024.za.pycon.org/users/brenden.taylor22/
# Talk URL             https://2024.za.pycon.org/talks/19-its-about-t...
# Speaker ID                                                           3
# Speaker ID.1                                                         3
# Name                                                    Brenden Taylor
# Profile URL          https://2024.za.pycon.org/users/brenden.taylor22/
# Photo URL                                           No photo available
# Twitter                                                            NaN
# GitHub                                                             NaN
# Fediverse                                                          NaN
# Bio Part 1           I am a data scientist at Praelexis, in Stellen...
# Bio Part 2                                                         NaN
# Bio Part 3                                                         NaN

# %% [markdown]
# # Join topics

# %%
# Load the topics file into pandas DataFrames
file_path_topics = 'data/topics.csv'
df_topics = pd.read_csv(file_path_topics)

# Merge the two DataFrames on 'Talk ID', and rename the 'Assigned Topic' column to 'Topic'
df = pd.merge(df, df_topics, on='Talk ID', how='left').rename(columns={'Assigned Topic': 'Topic'})

# %%
# Display the first few rows of the merged DataFrame to verify the data
df.head(3).T
# Out:
#                                                                      0  \
# Talk ID                                                              1
# Title                                          Applying AI with Python
# Abstract             Artificial Intelligence (AI) is transforming i...
# Speaker Name                                               Alex Conway
# Speaker Profile URL           https://2024.za.pycon.org/users/alxcnwy/
# Talk URL             https://2024.za.pycon.org/talks/11-applying-ai...
# Speaker ID                                                           1
# Speaker ID.1                                                         1
# Name                                                       Alex Conway
# Profile URL                   https://2024.za.pycon.org/users/alxcnwy/
# Photo URL                                           No photo available
# Twitter                                    https://twitter.com/alxcnwy
# GitHub                                      https://github.com/alxcnwy
# Fediverse                                                          NaN
# Bio Part 1            Twitter Profile link:https://twitter.com/alxcnwy
# Bio Part 2           Other Social:https://www.linkedin.com/in/alxcnwy/
# Bio Part 3                   github profile:https://github.com/alxcnwy
# Topic                                          AI and Machine Learning
#
#                                                                      1  \
# Talk ID                                                              2
# Title                Harnessing the Power of Community: Lessons fro...
# Abstract             Speedrunning, the art of completing video game...
# Speaker Name                                            Nunudzai Mrewa
# Speaker Profile URL         https://2024.za.pycon.org/users/JustNunuz/
# Talk URL             https://2024.za.pycon.org/talks/13-harnessing-...
# Speaker ID                                                           2
# Speaker ID.1                                                         2
# Name                                                    Nunudzai Mrewa
# Profile URL                 https://2024.za.pycon.org/users/JustNunuz/
# Photo URL                                           No photo available
# Twitter                                                            NaN
# GitHub                                    https://github.com/JustNunuz
# Fediverse                                                          NaN
# Bio Part 1           Twitter Profile link:https://x.com/_absolute_z3r0
# Bio Part 2             Other Social:https://www.linkedin.com/in/nunuz/
# Bio Part 3                 github profile:https://github.com/JustNunuz
# Topic                                     Community and Tech Education
#
#                                                                      2
# Talk ID                                                              3
# Title                It’s About Time: Time-Series Forecasting with ...
# Abstract             Along with the rise of “AI”, data-driven decis...
# Speaker Name                                            Brenden Taylor
# Speaker Profile URL  https://2024.za.pycon.org/users/brenden.taylor22/
# Talk URL             https://2024.za.pycon.org/talks/19-its-about-t...
# Speaker ID                                                           3
# Speaker ID.1                                                         3
# Name                                                    Brenden Taylor
# Profile URL          https://2024.za.pycon.org/users/brenden.taylor22/
# Photo URL                                           No photo available
# Twitter                                                            NaN
# GitHub                                                             NaN
# Fediverse                                                          NaN
# Bio Part 1           I am a data scientist at Praelexis, in Stellen...
# Bio Part 2                                                         NaN
# Bio Part 3                                                         NaN
# Topic                                             Time Series Analysis

# %% [markdown]
# Now we have topics too

# %% [markdown]
# # Transform - Enrich our data by scraping github and twitter

# %%
token = "github_pat_11ACB..."

# %% [markdown]
# ```
# {
#     "username": "alxcnwy",
#     "name": "Alex Conway",
#     "public_repos": 18,
#     "total_stars": 104,
#     "most_starred_repo": {
#         "name": "Deep-Neural-Networks-for-Video-Classification",
#         "stars": 44
#     },
#     "last_commit_datetime": "2024-10-02T11:26:04+00:00",
#     "hours_since_last_commit": 0.5807980566666667,
#     "followers": 44,
#     "following": 15,
#     "created_at": "2014-09-02T18:24:14+00:00",
#     "company": null,
#     "bio": "making something people want | \u27e0 \u20bf | \r\nycombinator\r\n W22 | won awards for AI projects from companies like Mercedes-Benz, NTT Japan, etc",
#     "location": "Cape Town",
#     "blog": "www.numberboost.com",
#     "email": null
# }
#
# ```

# %% [markdown]
# ## Scrape all github data where available

# %%
# Directory path where .txt files are located
data_directory = 'data/combined/'
output_csv_path = 'data/github.csv'

# Function to extract data from each .txt file
def extract_data_from_txt(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
    
    # Extract Speaker ID
    speaker_id_match = re.search(r"Speaker ID: (\d+)", content)
    speaker_id = speaker_id_match.group(1) if speaker_id_match else None
    
    # Extract GitHub URL (first URL that matches GitHub pattern)
    github_url_match = re.search(r"(https://github\.com/[a-zA-Z0-9_-]+)", content)
    github_url = github_url_match.group(1) if github_url_match else None
    
    # Return the extracted data
    return {
        "speaker_id": speaker_id,
        "github_url": github_url
    }

# Retry function with exponential backoff for handling API request errors
@retry(stop_max_attempt_number=1, wait_exponential_multiplier=1000, wait_exponential_max=10000)
def get_github_profile_data(profile_url):
    print("Scraping github for:", profile_url)
    try:
        # Extract username from profile URL
        username = profile_url.rstrip('/').split('/')[-1]
        
        # Get user information
        user = g.get_user(username)
        
        # Fetch all repos of the user
        repos = user.get_repos()
        
        # Data collection variables
        last_commit = None
        hours_since_last_commit = None
        total_stars = 0
        most_starred_repo = None
        most_stars = 0
        num_repos = repos.totalCount
        
        # Process repositories
        for repo in repos:
            total_stars += repo.stargazers_count
            if repo.stargazers_count > most_stars:
                most_stars = repo.stargazers_count
                most_starred_repo = repo
            
            # Find the latest commit
            try:
                commits = repo.get_commits()
                if commits.totalCount > 0:
                    latest_commit = commits[0].commit.author.date
                    if last_commit is None or latest_commit > last_commit:
                        last_commit = latest_commit
            except GithubException as e:
                # Skip repositories with issues (e.g., empty repositories)
                print(f"Skipping repository {repo.name} due to error: {e.data.get('message', str(e))}")
                continue
        
        # Calculate hours since last commit if available
        if last_commit:
            now = datetime.now(timezone.utc)
            hours_since_last_commit = (now - last_commit).total_seconds() / 3600

        # Prepare output as JSON
        data = {
            "username": user.login,
            "name": user.name,
            "public_repos": num_repos,
            "total_stars": total_stars,
            "most_starred_repo": {
                "name": most_starred_repo.name if most_starred_repo else None,
                "stars": most_stars
            },
            "last_commit_datetime": last_commit.isoformat() if last_commit else None,
            "hours_since_last_commit": hours_since_last_commit,
            "followers": user.followers,
            "following": user.following,
            "created_at": user.created_at.isoformat(),
            "company": user.company,
            "bio": user.bio,
            "location": user.location,
            "blog": user.blog,
            "email": user.email
        }

        return data
    except (GithubException, RetryError, MaxRetryError) as e:
        # Handle API-related errors and skip problematic profiles
        print(f"Error processing profile {profile_url}: {str(e)}")
        return None

# Function to process all .txt files and get the combined data
def process_all_txt_files(directory):
    combined_data = []
    
    # Loop through all files in the specified directory
    for i, filename in enumerate(os.listdir(directory)):
        print(f"{i}/{len(os.listdir(directory))}")
        if filename.endswith(".txt"):
            file_path = os.path.join(directory, filename)
            # Extract speaker ID and GitHub URL from the current file
            speaker_data = extract_data_from_txt(file_path)
            # Get GitHub profile data if GitHub URL is found
            if speaker_data["github_url"]:
                profile_data = get_github_profile_data(speaker_data["github_url"])
                speaker_data["github_profile_data"] = profile_data
            else:
                speaker_data["github_profile_data"] = None
            
            # Add to combined data if the profile data is successfully fetched
            combined_data.append(speaker_data)
    
    return combined_data

# Function to save the combined data to a CSV file
def save_to_csv(data, csv_file_path):
    with open(csv_file_path, mode='w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['speaker_id', 'github_url', 'username', 'name', 'public_repos', 'total_stars', 'most_starred_repo_name', 'most_starred_repo_stars', 'last_commit_datetime', 'hours_since_last_commit', 'followers', 'following', 'created_at', 'company', 'bio', 'location', 'blog', 'email']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()
        for item in data:
            github_data = item.get("github_profile_data", {})
            if github_data:  # Ensure the GitHub data is not None
                writer.writerow({
                    'speaker_id': item.get('speaker_id'),
                    'github_url': item.get('github_url'),
                    'username': github_data.get('username'),
                    'name': github_data.get('name'),
                    'public_repos': github_data.get('public_repos'),
                    'total_stars': github_data.get('total_stars'),
                    'most_starred_repo_name': github_data.get('most_starred_repo', {}).get('name'),
                    'most_starred_repo_stars': github_data.get('most_starred_repo', {}).get('stars'),
                    'last_commit_datetime': github_data.get('last_commit_datetime'),
                    'hours_since_last_commit': github_data.get('hours_since_last_commit'),
                    'followers': github_data.get('followers'),
                    'following': github_data.get('following'),
                    'created_at': github_data.get('created_at'),
                    'company': github_data.get('company'),
                    'bio': github_data.get('bio'),
                    'location': github_data.get('location'),
                    'blog': github_data.get('blog'),
                    'email': github_data.get('email')
                })

# Main code execution
all_speaker_data = process_all_txt_files(data_directory)

# Save the data to a CSV file
save_to_csv(all_speaker_data, output_csv_path)

# Print the JSON result
print(json.dumps(all_speaker_data, indent=4))
# Out:
# 0/35
# Scraping github for: https://github.com/sixfeetup
# 1/35
# Scraping github for: https://github.com/gijzelaerr
# Skipping repository gh_repo_test due to error: Git Repository is empty.
# Skipping repository owlcat due to error: Git Repository is empty.
# Skipping repository pages-test due to error: Git Repository is empty.
# Skipping repository playground due to error: Git Repository is empty.
# Skipping repository purify-debian due to error: Git Repository is empty.
# 2/35
# 3/35
# 4/35
# 5/35
# 6/35
# 7/35
# Scraping github for: https://github.com/luisdza
# 8/35
# Scraping github for: https://github.com/singhsegv
# 9/35
# Scraping github for: https://github.com/drnlm
# 10/35
# Scraping github for: https://github.com/Divya063
# Skipping repository cassandra_notes due to error: Git Repository is empty.
# Skipping repository Data-Science due to error: Git Repository is empty.
# Skipping repository lsmkv due to error: Git Repository is empty.
# Skipping repository twitter-clone due to error: Git Repository is empty.
# 11/35
# Scraping github for: https://github.com/adeline-pepela
# Skipping repository intellihousing due to error: Git Repository is empty.
# Skipping repository Statistics-fundamentals due to error: Git Repository is empty.
# 12/35
# Scraping github for: https://github.com/sheenarbw
# Skipping repository AndroidDemo due to error: Git Repository is empty.
# Skipping repository PyConZA-wiki due to error: Git Repository is empty.
# 13/35
# Scraping github for: https://github.com/sheenarbw
# Skipping repository AndroidDemo due to error: Git Repository is empty.
# Skipping repository PyConZA-wiki due to error: Git Repository is empty.
# 14/35
# 15/35
# Scraping github for: https://github.com/czue
# Skipping repository chrome-google-photos due to error: Git Repository is empty.
# 16/35
# Scraping github for: https://github.com/sheenarbw
# Skipping repository AndroidDemo due to error: Git Repository is empty.
# Skipping repository pres-power-to-the-educators-pyconza-2024 due to error: Not Found
# Skipping repository PyConZA-wiki due to error: Git Repository is empty.
# 17/35
# Scraping github for: https://github.com/emlearn
# 18/35
# Scraping github for: https://github.com/bmerry
# Error processing profile https://github.com/bmerry: HTTPSConnectionPool(host='api.github.com', port=443): Max retries exceeded with url: /repos/bmerry/PySPEAD/commits (Caused by ResponseError('too many 500 error responses'))
# 19/35
# Scraping github for: https://github.com/cityofcapetown
# Skipping repository docker_datascience_gpu due to error: Git Repository is empty.
# 20/35
# Scraping github for: https://github.com/coderquill
# Skipping repository GOTMania due to error: Git Repository is empty.
# Skipping repository Operating-System due to error: Git Repository is empty.
# Skipping repository OS due to error: Git Repository is empty.
# 21/35
# Scraping github for: https://github.com/Kanhalelor
# 22/35
# 23/35
# Scraping github for: https://github.com/alxcnwy
# 24/35
# 25/35
# Scraping github for: https://github.com/jbeyers
# 26/35
# 27/35
# Scraping github for: https://github.com/JustNunuz
# 28/35
# Scraping github for: https://github.com/DuToitSpies
# 29/35
# Scraping github for: https://github.com/kode2go
# Skipping repository courses due to error: Git Repository is empty.
# Skipping repository html2go due to error: Git Repository is empty.
# Skipping repository kode2r due to error: Repository access blocked
# Skipping repository python-classes due to error: Git Repository is empty.
# 30/35
# Scraping github for: https://github.com/schalkventer
# Skipping repository codebridge-youth-portal due to error: Git Repository is empty.
# Skipping repository data-first-react due to error: Git Repository is empty.
# Skipping repository data-oriented-javascript due to error: Git Repository is empty.
# Skipping repository doc-formats due to error: Git Repository is empty.
# Skipping repository fizim due to error: Git Repository is empty.
# Skipping repository gatsby-canvas due to error: Git Repository is empty.
# Skipping repository Harel due to error: Git Repository is empty.
# Skipping repository html-charts due to error: Git Repository is empty.
# Skipping repository html-css-cheatsheet due to error: Git Repository is empty.
# Skipping repository hypertext-markup-object due to error: Git Repository is empty.
# Skipping repository jsp-example due to error: Git Repository is empty.
# Skipping repository kinetica due to error: Git Repository is empty.
# Skipping repository larva-life due to error: Git Repository is empty.
# Skipping repository learn-js due to error: Git Repository is empty.
# Skipping repository microde due to error: Git Repository is empty.
# Skipping repository nodb due to error: Git Repository is empty.
# Skipping repository offline-queue due to error: Git Repository is empty.
# Skipping repository open-mental-health-repository due to error: Git Repository is empty.
# Skipping repository palatable due to error: Git Repository is empty.
# Skipping repository react-offline-app due to error: Git Repository is empty.
# Skipping repository slides due to error: Git Repository is empty.
# Skipping repository tech-goes-mental due to error: Git Repository is empty.
# Skipping repository test due to error: Git Repository is empty.
# Skipping repository test-repo due to error: Git Repository is empty.
# Skipping repository timespan due to error: Git Repository is empty.
# Skipping repository tmin due to error: Git Repository is empty.
# Skipping repository turnstile due to error: Git Repository is empty.
# Skipping repository virtual-mule due to error: Git Repository is empty.
# Skipping repository voidb due to error: Git Repository is empty.
# 31/35
# 32/35
# Scraping github for: https://github.com/sjnarmstrong
# 33/35
# Scraping github for: https://github.com/nawtybean
# Skipping repository AKTraining due to error: Git Repository is empty.
# 34/35
# Scraping github for: https://github.com/ruankie
# [
#     {
#         "speaker_id": "8",
#         "github_url": "https://github.com/sixfeetup",
#         "github_profile_data": {
#             "username": "sixfeetup",
#             "name": "Six Feet Up",
#             "public_repos": 127,
#             "total_stars": 210,
#             "most_starred_repo": {
#                 "name": "scaf",
#                 "stars": 79
#             },
#             "last_commit_datetime": "2024-09-25T17:04:43+00:00",
#             "hours_since_last_commit": 164.0354158066667,
#             "followers": 19,
#             "following": 0,
#             "created_at": "2011-09-08T20:39:11+00:00",
#             "company": null,
#             "bio": "Accelerating IMPACT with App Dev, AI & Big Data",
#             "location": "Fishers, IN",
#             "blog": "http://www.sixfeetup.com",
#             "email": "info@sixfeetup.com"
#         }
#     },
#     {
#         "speaker_id": "20",
#         "github_url": "https://github.com/gijzelaerr",
#         "github_profile_data": {
#             "username": "gijzelaerr",
#             "name": "Gijs Molenaar",
#             "public_repos": 172,
#             "total_stars": 748,
#             "most_starred_repo": {
#                 "name": "python-snap7",
#                 "stars": 648
#             },
#             "last_commit_datetime": "2024-09-17T16:20:59+00:00",
#             "hours_since_last_commit": 356.8318311875,
#             "followers": 188,
#             "following": 111,
#             "created_at": "2010-07-08T11:22:39+00:00",
#             "company": "spotify",
#             "bio": "astro software composer, music brewer, beer programmer, senior system engineer @spotify",
#             "location": "Amsterdam - Windhoek",
#             "blog": "http://pythonic.nl",
#             "email": "gijsmolenaar@gmail.com"
#         }
#     },
#     {
#         "speaker_id": "34",
#         "github_url": null,
#         "github_profile_data": null
#     },
#     {
#         "speaker_id": "33",
#         "github_url": null,
#         "github_profile_data": null
#     },
#     {
#         "speaker_id": "19",
#         "github_url": null,
#         "github_profile_data": null
#     },
#     {
#         "speaker_id": "7",
#         "github_url": null,
#         "github_profile_data": null
#     },
#     {
#         "speaker_id": "35",
#         "github_url": null,
#         "github_profile_data": null
#     },
#     {
#         "speaker_id": "21",
#         "github_url": "https://github.com/luisdza",
#         "github_profile_data": {
#             "username": "luisdza",
#             "name": "Luis de Sousa",
#             "public_repos": 8,
#             "total_stars": 3,
#             "most_starred_repo": {
#                 "name": "aerialmzansi-website",
#                 "stars": 2
#             },
#             "last_commit_datetime": "2024-08-22T13:24:29+00:00",
#             "hours_since_last_commit": 983.7772850216667,
#             "followers": 23,
#             "following": 112,
#             "created_at": "2014-04-12T05:41:28+00:00",
#             "company": "@Syeop",
#             "bio": "Creating and dreaming",
#             "location": "Johannesburg, South Africa",
#             "blog": "",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "22",
#         "github_url": "https://github.com/singhsegv",
#         "github_profile_data": {
#             "username": "singhsegv",
#             "name": "Rajdeep",
#             "public_repos": 56,
#             "total_stars": 51,
#             "most_starred_repo": {
#                 "name": "kitaab_bot",
#                 "stars": 12
#             },
#             "last_commit_datetime": "2024-09-23T09:53:19+00:00",
#             "hours_since_last_commit": 219.31917223972223,
#             "followers": 63,
#             "following": 209,
#             "created_at": "2015-03-13T17:19:37+00:00",
#             "company": null,
#             "bio": "Software Engineering, Robotics and Computer Vision.",
#             "location": "Bangalore",
#             "blog": "singhsegv.github.io",
#             "email": "iamrajdeep1008@gmail.com"
#         }
#     },
#     {
#         "speaker_id": "32",
#         "github_url": "https://github.com/drnlm",
#         "github_profile_data": {
#             "username": "drnlm",
#             "name": "Neil Muller",
#             "public_repos": 30,
#             "total_stars": 5,
#             "most_starred_repo": {
#                 "name": "matplotlib-py3",
#                 "stars": 1
#             },
#             "last_commit_datetime": "2024-09-29T14:11:56+00:00",
#             "hours_since_last_commit": 71.0211160636111,
#             "followers": 7,
#             "following": 0,
#             "created_at": "2011-02-28T09:19:10+00:00",
#             "company": null,
#             "bio": null,
#             "location": "Cape Town, South Africa",
#             "blog": "",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "26",
#         "github_url": "https://github.com/Divya063",
#         "github_profile_data": {
#             "username": "Divya063",
#             "name": "Divya Rani",
#             "public_repos": 190,
#             "total_stars": 17,
#             "most_starred_repo": {
#                 "name": "distributedKV",
#                 "stars": 4
#             },
#             "last_commit_datetime": "2024-08-29T13:34:16+00:00",
#             "hours_since_last_commit": 815.735070125,
#             "followers": 134,
#             "following": 82,
#             "created_at": "2016-08-24T09:28:22+00:00",
#             "company": null,
#             "bio": "\r\n    Contributor @kubernetes-sigs | CKA | GSoC'19 @CERN | Outreachy '17 @opendatakit\r\n\r\n\r\n\r\n",
#             "location": null,
#             "blog": "",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "25",
#         "github_url": "https://github.com/adeline-pepela",
#         "github_profile_data": {
#             "username": "adeline-pepela",
#             "name": "Adeline Makokha",
#             "public_repos": 39,
#             "total_stars": 0,
#             "most_starred_repo": {
#                 "name": null,
#                 "stars": 0
#             },
#             "last_commit_datetime": "2024-09-16T12:50:07+00:00",
#             "hours_since_last_commit": 384.48877001611106,
#             "followers": 13,
#             "following": 9,
#             "created_at": "2021-06-08T13:20:20+00:00",
#             "company": null,
#             "bio": "Software Developer, 2X AWS Certified, Telecommunication and IT",
#             "location": "Kenya",
#             "blog": "",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "31",
#         "github_url": "https://github.com/sheenarbw",
#         "github_profile_data": {
#             "username": "sheenarbw",
#             "name": "sheenarbw",
#             "public_repos": 76,
#             "total_stars": 22,
#             "most_starred_repo": {
#                 "name": "tutorial-airflow",
#                 "stars": 6
#             },
#             "last_commit_datetime": "2024-10-02T13:00:38+00:00",
#             "hours_since_last_commit": 0.3476021816666667,
#             "followers": 77,
#             "following": 12,
#             "created_at": "2011-03-30T11:39:05+00:00",
#             "company": null,
#             "bio": null,
#             "location": null,
#             "blog": "https://sheenaoc.com",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "17",
#         "github_url": "https://github.com/sheenarbw",
#         "github_profile_data": {
#             "username": "sheenarbw",
#             "name": "sheenarbw",
#             "public_repos": 76,
#             "total_stars": 22,
#             "most_starred_repo": {
#                 "name": "tutorial-airflow",
#                 "stars": 6
#             },
#             "last_commit_datetime": "2024-10-02T13:00:38+00:00",
#             "hours_since_last_commit": 0.37692676583333334,
#             "followers": 77,
#             "following": 12,
#             "created_at": "2011-03-30T11:39:05+00:00",
#             "company": null,
#             "bio": null,
#             "location": null,
#             "blog": "https://sheenaoc.com",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "23",
#         "github_url": null,
#         "github_profile_data": null
#     },
#     {
#         "speaker_id": "29",
#         "github_url": "https://github.com/czue",
#         "github_profile_data": {
#             "username": "czue",
#             "name": "Cory Zue",
#             "public_repos": 67,
#             "total_stars": 1016,
#             "most_starred_repo": {
#                 "name": "celery-progress",
#                 "stars": 464
#             },
#             "last_commit_datetime": "2024-09-26T13:58:03+00:00",
#             "hours_since_last_commit": 143.44807943666666,
#             "followers": 343,
#             "following": 41,
#             "created_at": "2009-03-24T15:34:08+00:00",
#             "company": "SaaS Pegasus, Dimagi",
#             "bio": "Web developer and product maker. @dimagi",
#             "location": "Cape Town, South Africa",
#             "blog": "http://www.coryzue.com/",
#             "email": "cory@coryzue.com"
#         }
#     },
#     {
#         "speaker_id": "30",
#         "github_url": "https://github.com/sheenarbw",
#         "github_profile_data": {
#             "username": "sheenarbw",
#             "name": "sheenarbw",
#             "public_repos": 76,
#             "total_stars": 22,
#             "most_starred_repo": {
#                 "name": "tutorial-airflow",
#                 "stars": 6
#             },
#             "last_commit_datetime": "2024-09-23T12:49:09+00:00",
#             "hours_since_last_commit": 216.62495496194444,
#             "followers": 77,
#             "following": 12,
#             "created_at": "2011-03-30T11:39:05+00:00",
#             "company": null,
#             "bio": null,
#             "location": null,
#             "blog": "https://sheenaoc.com",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "24",
#         "github_url": "https://github.com/emlearn",
#         "github_profile_data": {
#             "username": "emlearn",
#             "name": null,
#             "public_repos": 2,
#             "total_stars": 546,
#             "most_starred_repo": {
#                 "name": "emlearn",
#                 "stars": 483
#             },
#             "last_commit_datetime": "2024-10-01T00:07:57+00:00",
#             "hours_since_last_commit": 37.31298744111111,
#             "followers": 23,
#             "following": 0,
#             "created_at": "2018-07-18T12:41:12+00:00",
#             "company": null,
#             "bio": "Machine Learning for Microcontrollers and Embedded Devices",
#             "location": null,
#             "blog": "https://emlearn.org",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "18",
#         "github_url": "https://github.com/bmerry",
#         "github_profile_data": null
#     },
#     {
#         "speaker_id": "13",
#         "github_url": "https://github.com/cityofcapetown",
#         "github_profile_data": {
#             "username": "cityofcapetown",
#             "name": "City of Cape Town",
#             "public_repos": 44,
#             "total_stars": 20,
#             "most_starred_repo": {
#                 "name": "loadshedding-signal-bot",
#                 "stars": 4
#             },
#             "last_commit_datetime": "2024-09-28T11:56:43+00:00",
#             "hours_since_last_commit": 97.5403705588889,
#             "followers": 37,
#             "following": 0,
#             "created_at": "2018-07-03T06:38:25+00:00",
#             "company": null,
#             "bio": "Public code from the City of Cape Town. Maintained by the Data Science branch in Organisational Performance Monitoring Dept., Future Planning & Resilience Dir.",
#             "location": "Cape Town, South Africa",
#             "blog": "https://www.capetown.gov.za",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "27",
#         "github_url": "https://github.com/coderquill",
#         "github_profile_data": {
#             "username": "coderquill",
#             "name": "Rupali Kavale",
#             "public_repos": 75,
#             "total_stars": 3,
#             "most_starred_repo": {
#                 "name": "topstar",
#                 "stars": 3
#             },
#             "last_commit_datetime": "2024-09-23T00:53:24+00:00",
#             "hours_since_last_commit": 228.62767554277778,
#             "followers": 4,
#             "following": 2,
#             "created_at": "2017-07-29T09:42:56+00:00",
#             "company": null,
#             "bio": null,
#             "location": null,
#             "blog": "",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "28",
#         "github_url": "https://github.com/Kanhalelor",
#         "github_profile_data": {
#             "username": "Kanhalelor",
#             "name": "Robson",
#             "public_repos": 54,
#             "total_stars": 2,
#             "most_starred_repo": {
#                 "name": "CSS-Flexbox-Layout",
#                 "stars": 1
#             },
#             "last_commit_datetime": "2024-07-12T12:31:38+00:00",
#             "hours_since_last_commit": 1969.0142931358332,
#             "followers": 10,
#             "following": 32,
#             "created_at": "2019-02-27T16:55:09+00:00",
#             "company": null,
#             "bio": "\ud83d\udda5\ufe0f Writing Code | \ud83d\udca1 In love with uncertainty & appreciation \u2728",
#             "location": "Swakopmund",
#             "blog": "https://kanhalelor.github.io/",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "14",
#         "github_url": null,
#         "github_profile_data": null
#     },
#     {
#         "speaker_id": "1",
#         "github_url": "https://github.com/alxcnwy",
#         "github_profile_data": {
#             "username": "alxcnwy",
#             "name": "Alex Conway",
#             "public_repos": 18,
#             "total_stars": 104,
#             "most_starred_repo": {
#                 "name": "Deep-Neural-Networks-for-Video-Classification",
#                 "stars": 44
#             },
#             "last_commit_datetime": "2024-10-02T11:26:04+00:00",
#             "hours_since_last_commit": 2.1146393786111113,
#             "followers": 44,
#             "following": 15,
#             "created_at": "2014-09-02T18:24:14+00:00",
#             "company": null,
#             "bio": "making something people want | \u27e0 \u20bf | \r\nycombinator\r\n W22 | won awards for AI projects from companies like Mercedes-Benz, NTT Japan, etc",
#             "location": "Cape Town",
#             "blog": "www.numberboost.com",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "3",
#         "github_url": null,
#         "github_profile_data": null
#     },
#     {
#         "speaker_id": "16",
#         "github_url": "https://github.com/jbeyers",
#         "github_profile_data": {
#             "username": "jbeyers",
#             "name": "Johan Beyers",
#             "public_repos": 42,
#             "total_stars": 57,
#             "most_starred_repo": {
#                 "name": "django-prelaunch",
#                 "stars": 36
#             },
#             "last_commit_datetime": "2024-08-14T04:57:28+00:00",
#             "hours_since_last_commit": 1184.6092403975,
#             "followers": 15,
#             "following": 8,
#             "created_at": "2010-06-28T10:04:31+00:00",
#             "company": "Juizi CC",
#             "bio": "Electronic engineer, builder of web software, Maker.",
#             "location": "Stellenbosch, South Africa",
#             "blog": "http://johan.beyers.co.za/",
#             "email": "johan@juizi.com"
#         }
#     },
#     {
#         "speaker_id": "15",
#         "github_url": null,
#         "github_profile_data": null
#     },
#     {
#         "speaker_id": "2",
#         "github_url": "https://github.com/JustNunuz",
#         "github_profile_data": {
#             "username": "JustNunuz",
#             "name": "Nunudzai Mrewa",
#             "public_repos": 10,
#             "total_stars": 0,
#             "most_starred_repo": {
#                 "name": null,
#                 "stars": 0
#             },
#             "last_commit_datetime": "2024-09-13T13:33:13+00:00",
#             "hours_since_last_commit": 456.01818747666664,
#             "followers": 4,
#             "following": 37,
#             "created_at": "2019-12-23T09:07:22+00:00",
#             "company": null,
#             "bio": "Hi there! I'm a security researcher and pentester.",
#             "location": null,
#             "blog": "",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "11",
#         "github_url": "https://github.com/DuToitSpies",
#         "github_profile_data": {
#             "username": "DuToitSpies",
#             "name": "Du Toit Spies",
#             "public_repos": 11,
#             "total_stars": 1,
#             "most_starred_repo": {
#                 "name": "cython",
#                 "stars": 1
#             },
#             "last_commit_datetime": "2024-08-10T18:13:17+00:00",
#             "hours_since_last_commit": 1267.3555367611111,
#             "followers": 0,
#             "following": 0,
#             "created_at": "2021-03-31T11:46:28+00:00",
#             "company": "University of Cape Town",
#             "bio": null,
#             "location": "Cape Town",
#             "blog": "",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "12",
#         "github_url": "https://github.com/kode2go",
#         "github_profile_data": {
#             "username": "kode2go",
#             "name": "kode2go",
#             "public_repos": 74,
#             "total_stars": 7,
#             "most_starred_repo": {
#                 "name": "nithecs",
#                 "stars": 2
#             },
#             "last_commit_datetime": "2024-06-01T22:11:01+00:00",
#             "hours_since_last_commit": 2943.424766140555,
#             "followers": 6,
#             "following": 1,
#             "created_at": "2017-06-23T19:03:23+00:00",
#             "company": null,
#             "bio": null,
#             "location": null,
#             "blog": "",
#             "email": "brsbin001@myuct.ac.za"
#         }
#     },
#     {
#         "speaker_id": "6",
#         "github_url": "https://github.com/schalkventer",
#         "github_profile_data": {
#             "username": "schalkventer",
#             "name": "Schalk Venter",
#             "public_repos": 171,
#             "total_stars": 165,
#             "most_starred_repo": {
#                 "name": "schalkventer.me",
#                 "stars": 17
#             },
#             "last_commit_datetime": "2024-09-29T08:11:23+00:00",
#             "hours_since_last_commit": 77.48498521722223,
#             "followers": 365,
#             "following": 504,
#             "created_at": "2015-09-13T08:55:34+00:00",
#             "company": "Co-founder at @fedsa",
#             "bio": "\ud83d\udcbb Software Engineering\r\n| \ud83c\udfa8 Interaction Design \r\n| \ud83d\udcda Mentoring and Teaching \r\n| \ud83e\udde0 Destigmatizing Mental Illness",
#             "location": "Cape Town, South Africa",
#             "blog": "https://schalkventer.me",
#             "email": "venterschalk@gmail.com"
#         }
#     },
#     {
#         "speaker_id": "5",
#         "github_url": null,
#         "github_profile_data": null
#     },
#     {
#         "speaker_id": "10",
#         "github_url": "https://github.com/sjnarmstrong",
#         "github_profile_data": {
#             "username": "sjnarmstrong",
#             "name": "Sholto Armstrong",
#             "public_repos": 27,
#             "total_stars": 131,
#             "most_starred_repo": {
#                 "name": "gray-code-structured-light",
#                 "stars": 112
#             },
#             "last_commit_datetime": "2024-04-09T17:40:16+00:00",
#             "hours_since_last_commit": 4220.015618723889,
#             "followers": 20,
#             "following": 7,
#             "created_at": "2018-12-29T20:55:43+00:00",
#             "company": "Capitec Bank",
#             "bio": null,
#             "location": "Johannesburg, South Africa",
#             "blog": "https://sjnarmstrong.com/",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "9",
#         "github_url": "https://github.com/nawtybean",
#         "github_profile_data": {
#             "username": "nawtybean",
#             "name": "Shaun De Ponte",
#             "public_repos": 16,
#             "total_stars": 4,
#             "most_starred_repo": {
#                 "name": "KickstarterPrediction",
#                 "stars": 2
#             },
#             "last_commit_datetime": "2024-09-25T11:53:39+00:00",
#             "hours_since_last_commit": 169.79982544333333,
#             "followers": 5,
#             "following": 3,
#             "created_at": "2018-06-12T12:05:02+00:00",
#             "company": "Private",
#             "bio": "Data Engineer and Software Engineer",
#             "location": "South Africa",
#             "blog": "deponte.co.za",
#             "email": null
#         }
#     },
#     {
#         "speaker_id": "4",
#         "github_url": "https://github.com/ruankie",
#         "github_profile_data": {
#             "username": "ruankie",
#             "name": "Ruan Pretorius",
#             "public_repos": 71,
#             "total_stars": 112,
#             "most_starred_repo": {
#                 "name": "ecrivai",
#                 "stars": 68
#             },
#             "last_commit_datetime": "2024-10-02T00:42:55+00:00",
#             "hours_since_last_commit": 13.010268252222223,
#             "followers": 19,
#             "following": 10,
#             "created_at": "2019-12-05T13:17:03+00:00",
#             "company": "@melio-consulting",
#             "bio": "Data Scientist",
#             "location": "South Africa",
#             "blog": "https://ruankie.github.io/",
#             "email": null
#         }
#     }
# ]

# %% [markdown]
# # Create final .txt documents with all the enriched data

# %%
dfg = pd.read_csv("data/github.csv")
dfg
# Out:
#     speaker_id                         github_url        username  \
# 0            8       https://github.com/sixfeetup       sixfeetup
# 1           20      https://github.com/gijzelaerr      gijzelaerr
# 2           21         https://github.com/luisdza         luisdza
# 3           22       https://github.com/singhsegv       singhsegv
# 4           32           https://github.com/drnlm           drnlm
# 5           26        https://github.com/Divya063        Divya063
# 6           25  https://github.com/adeline-pepela  adeline-pepela
# 7           31       https://github.com/sheenarbw       sheenarbw
# 8           17       https://github.com/sheenarbw       sheenarbw
# 9           29            https://github.com/czue            czue
# 10          30       https://github.com/sheenarbw       sheenarbw
# 11          24         https://github.com/emlearn         emlearn
# 12          13  https://github.com/cityofcapetown  cityofcapetown
# 13          27      https://github.com/coderquill      coderquill
# 14          28      https://github.com/Kanhalelor      Kanhalelor
# 15           1         https://github.com/alxcnwy         alxcnwy
# 16          16         https://github.com/jbeyers         jbeyers
# 17           2       https://github.com/JustNunuz       JustNunuz
# 18          11     https://github.com/DuToitSpies     DuToitSpies
# 19          12         https://github.com/kode2go         kode2go
# 20           6    https://github.com/schalkventer    schalkventer
# 21          10    https://github.com/sjnarmstrong    sjnarmstrong
# 22           9       https://github.com/nawtybean       nawtybean
# 23           4         https://github.com/ruankie         ruankie
#
#                  name  public_repos  total_stars  \
# 0         Six Feet Up           127          210
# 1       Gijs Molenaar           172          748
# 2       Luis de Sousa             8            3
# 3             Rajdeep            56           51
# 4         Neil Muller            30            5
# 5          Divya Rani           190           17
# 6     Adeline Makokha            39            0
# 7           sheenarbw            76           22
# 8           sheenarbw            76           22
# 9            Cory Zue            67         1016
# 10          sheenarbw            76           22
# 11                NaN             2          546
# 12  City of Cape Town            44           20
# 13      Rupali Kavale            75            3
# 14             Robson            54            2
# 15        Alex Conway            18          104
# 16       Johan Beyers            42           57
# 17     Nunudzai Mrewa            10            0
# 18      Du Toit Spies            11            1
# 19            kode2go            74            7
# 20      Schalk Venter           171          165
# 21   Sholto Armstrong            27          131
# 22     Shaun De Ponte            16            4
# 23     Ruan Pretorius            71          112
#
#                            most_starred_repo_name  most_starred_repo_stars  \
# 0                                            scaf                       79
# 1                                    python-snap7                      648
# 2                            aerialmzansi-website                        2
# 3                                      kitaab_bot                       12
# 4                                  matplotlib-py3                        1
# 5                                   distributedKV                        4
# 6                                             NaN                        0
# 7                                tutorial-airflow                        6
# 8                                tutorial-airflow                        6
# 9                                 celery-progress                      464
# 10                               tutorial-airflow                        6
# 11                                        emlearn                      483
# 12                        loadshedding-signal-bot                        4
# 13                                        topstar                        3
# 14                             CSS-Flexbox-Layout                        1
# 15  Deep-Neural-Networks-for-Video-Classification                       44
# 16                               django-prelaunch                       36
# 17                                            NaN                        0
# 18                                         cython                        1
# 19                                        nithecs                        2
# 20                                schalkventer.me                       17
# 21                     gray-code-structured-light                      112
# 22                          KickstarterPrediction                        2
# 23                                        ecrivai                       68
#
#          last_commit_datetime  hours_since_last_commit  followers  following  \
# 0   2024-09-25T17:04:43+00:00               164.035416         19          0
# 1   2024-09-17T16:20:59+00:00               356.831831        188        111
# 2   2024-08-22T13:24:29+00:00               983.777285         23        112
# 3   2024-09-23T09:53:19+00:00               219.319172         63        209
# 4   2024-09-29T14:11:56+00:00                71.021116          7          0
# 5   2024-08-29T13:34:16+00:00               815.735070        134         82
# 6   2024-09-16T12:50:07+00:00               384.488770         13          9
# 7   2024-10-02T13:00:38+00:00                 0.347602         77         12
# 8   2024-10-02T13:00:38+00:00                 0.376927         77         12
# 9   2024-09-26T13:58:03+00:00               143.448079        343         41
# 10  2024-09-23T12:49:09+00:00               216.624955         77         12
# 11  2024-10-01T00:07:57+00:00                37.312987         23          0
# 12  2024-09-28T11:56:43+00:00                97.540371         37          0
# 13  2024-09-23T00:53:24+00:00               228.627676          4          2
# 14  2024-07-12T12:31:38+00:00              1969.014293         10         32
# 15  2024-10-02T11:26:04+00:00                 2.114639         44         15
# 16  2024-08-14T04:57:28+00:00              1184.609240         15          8
# 17  2024-09-13T13:33:13+00:00               456.018187          4         37
# 18  2024-08-10T18:13:17+00:00              1267.355537          0          0
# 19  2024-06-01T22:11:01+00:00              2943.424766          6          1
# 20  2024-09-29T08:11:23+00:00                77.484985        365        504
# 21  2024-04-09T17:40:16+00:00              4220.015619         20          7
# 22  2024-09-25T11:53:39+00:00               169.799825          5          3
# 23  2024-10-02T00:42:55+00:00                13.010268         19         10
#
#                    created_at                  company  \
# 0   2011-09-08T20:39:11+00:00                      NaN
# 1   2010-07-08T11:22:39+00:00                  spotify
# 2   2014-04-12T05:41:28+00:00                   @Syeop
# 3   2015-03-13T17:19:37+00:00                      NaN
# 4   2011-02-28T09:19:10+00:00                      NaN
# 5   2016-08-24T09:28:22+00:00                      NaN
# 6   2021-06-08T13:20:20+00:00                      NaN
# 7   2011-03-30T11:39:05+00:00                      NaN
# 8   2011-03-30T11:39:05+00:00                      NaN
# 9   2009-03-24T15:34:08+00:00     SaaS Pegasus, Dimagi
# 10  2011-03-30T11:39:05+00:00                      NaN
# 11  2018-07-18T12:41:12+00:00                      NaN
# 12  2018-07-03T06:38:25+00:00                      NaN
# 13  2017-07-29T09:42:56+00:00                      NaN
# 14  2019-02-27T16:55:09+00:00                      NaN
# 15  2014-09-02T18:24:14+00:00                      NaN
# 16  2010-06-28T10:04:31+00:00                 Juizi CC
# 17  2019-12-23T09:07:22+00:00                      NaN
# 18  2021-03-31T11:46:28+00:00  University of Cape Town
# 19  2017-06-23T19:03:23+00:00                      NaN
# 20  2015-09-13T08:55:34+00:00     Co-founder at @fedsa
# 21  2018-12-29T20:55:43+00:00             Capitec Bank
# 22  2018-06-12T12:05:02+00:00                  Private
# 23  2019-12-05T13:17:03+00:00        @melio-consulting
#
#                                                   bio  \
# 0     Accelerating IMPACT with App Dev, AI & Big Data
# 1   astro software composer, music brewer, beer pr...
# 2                               Creating and dreaming
# 3   Software Engineering, Robotics and Computer Vi...
# 4                                                 NaN
# 5   \r\n    Contributor @kubernetes-sigs | CKA | G...
# 6   Software Developer, 2X AWS Certified, Telecomm...
# 7                                                 NaN
# 8                                                 NaN
# 9            Web developer and product maker. @dimagi
# 10                                                NaN
# 11  Machine Learning for Microcontrollers and Embe...
# 12  Public code from the City of Cape Town. Mainta...
# 13                                                NaN
# 14  🖥️ Writing Code | 💡 In love with uncertainty &...
# 15  making something people want | ⟠ ₿ | \r\nycomb...
# 16  Electronic engineer, builder of web software, ...
# 17  Hi there! I'm a security researcher and pentes...
# 18                                                NaN
# 19                                                NaN
# 20  💻 Software Engineering\r\n| 🎨 Interaction Desi...
# 21                                                NaN
# 22                Data Engineer and Software Engineer
# 23                                     Data Scientist
#
#                       location                           blog  \
# 0                  Fishers, IN       http://www.sixfeetup.com
# 1         Amsterdam - Windhoek             http://pythonic.nl
# 2   Johannesburg, South Africa                            NaN
# 3                    Bangalore            singhsegv.github.io
# 4      Cape Town, South Africa                            NaN
# 5                          NaN                            NaN
# 6                        Kenya                            NaN
# 7                          NaN           https://sheenaoc.com
# 8                          NaN           https://sheenaoc.com
# 9      Cape Town, South Africa        http://www.coryzue.com/
# 10                         NaN           https://sheenaoc.com
# 11                         NaN            https://emlearn.org
# 12     Cape Town, South Africa    https://www.capetown.gov.za
# 13                         NaN                            NaN
# 14                  Swakopmund  https://kanhalelor.github.io/
# 15                   Cape Town            www.numberboost.com
# 16  Stellenbosch, South Africa     http://johan.beyers.co.za/
# 17                         NaN                            NaN
# 18                   Cape Town                            NaN
# 19                         NaN                            NaN
# 20     Cape Town, South Africa        https://schalkventer.me
# 21  Johannesburg, South Africa      https://sjnarmstrong.com/
# 22                South Africa                  deponte.co.za
# 23                South Africa     https://ruankie.github.io/
#
#                        email
# 0         info@sixfeetup.com
# 1     gijsmolenaar@gmail.com
# 2                        NaN
# 3   iamrajdeep1008@gmail.com
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9           cory@coryzue.com
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16           johan@juizi.com
# 17                       NaN
# 18                       NaN
# 19     brsbin001@myuct.ac.za
# 20    venterschalk@gmail.com
# 21                       NaN
# 22                       NaN
# 23                       NaN

# %%
import os
import pandas as pd

# Define the input directory with the existing .txt files and the dataframe dfg
input_dir = 'data/combined/'
output_dir = 'data/documents/'

# Ensure the output directory exists (in case you want to save a copy there)
os.makedirs(output_dir, exist_ok=True)

# Function to extract Speaker ID from a given .txt file
def extract_speaker_id_from_txt(filepath):
    with open(filepath, 'r') as file:
        for line in file:
            if line.startswith("Speaker ID:"):
                return int(line.split(":")[1].strip())  # Extract and return the Speaker ID
    return None

# Loop through all .txt files in the directory
for filename in os.listdir(input_dir):
    if filename.endswith(".txt"):
        file_path = os.path.join(input_dir, filename)
        
        # Extract Speaker ID from the .txt file
        speaker_id_in_file = extract_speaker_id_from_txt(file_path)
        
        # Find matching row in the dataframe based on speaker_id
        matching_row = dfg[dfg['speaker_id'] == speaker_id_in_file]
        
        if not matching_row.empty:
            row = matching_row.iloc[0]  # Get the first (and only) matching row
            
            # Append Github data to the existing file
            with open(file_path, 'a') as f:
                f.write("\n--- Github ---\n")
                for column in dfg.columns:
                    value = row[column]
                    if pd.isna(value):
                        value = ""  # Replace NaN values with empty strings
                    f.write(f"{column}: {value}\n")

# %% [markdown]
# # Load documents into vector store

# %%
openai_api_key = "sk-proj-aXO5P8Fe_i0K6yeE..."

# %% [markdown]
# ## load vectorstore

# %%
import os
import openai
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.docstore.document import Document

# Set your OpenAI API key
openai.api_key = openai_api_key

# Path to your documents folder
docs_folder = "data/documents/"

# Initialize OpenAI embeddings
embedding_model = OpenAIEmbeddings(model="text-embedding-ada-002")

# Read all text files from the directory
documents = []
for filename in os.listdir(docs_folder):
    if filename.endswith(".txt"):
        with open(os.path.join(docs_folder, filename), "r") as file:
            text = file.read()
            doc = Document(page_content=text)
            documents.append(doc)

# Embed the documents and store embeddings in FAISS
vectorstore = FAISS.from_documents(documents, embedding_model)

# Save FAISS index
vectorstore.save_local("faiss_index")
# Out:
# /var/folders/k3/c3xvj_bs4zbghyks6ph03td80000gn/T/ipykernel_8881/631321031.py:14: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embedding_model = OpenAIEmbeddings(model="text-embedding-ada-002")

# %% [markdown]
# # Load structured data into SQLite

# %%
# Normalize column names function
def normalize_column_names(df):
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
    return df

# Load CSV files into Pandas DataFrames
github_df = pd.read_csv('data/github.csv')
speakers_df = pd.read_csv('data/speakers.csv')
talks_df = pd.read_csv('data/talks.csv')
topics_df = pd.read_csv('data/topics.csv')

# Normalize column names
github_df = normalize_column_names(github_df)
speakers_df = normalize_column_names(speakers_df)
talks_df = normalize_column_names(talks_df)
topics_df = normalize_column_names(topics_df)

# Create a SQLite connection
conn = sqlite3.connect('data/conference_data.db')

# Save the dataframes to SQLite
github_df.to_sql('github', conn, if_exists='replace', index=False)
speakers_df.to_sql('speakers', conn, if_exists='replace', index=False)
talks_df.to_sql('talks', conn, if_exists='replace', index=False)
topics_df.to_sql('topics', conn, if_exists='replace', index=False)
# Out:
# 36

# %% [markdown]
# ## Test Query Database

# %%
# Create a SQLite connection
conn = sqlite3.connect('data/conference_data.db')

# Example join queries
with conn:
    # Query to get speaker details along with their GitHub information
    query1 = '''
    SELECT s.name, s.twitter, s.github, g.username, g.public_repos, g.followers
    FROM speakers s
    JOIN github g ON s.github = g.github_url
    LIMIT 5;
    '''
    result1 = pd.read_sql_query(query1, conn)
    print("Speaker GitHub Information:")
    print(result1)

    # Query to get talks and their associated topics
    query2 = '''
    SELECT t.title, t.abstract, p.assigned_topic
    FROM talks t
    JOIN topics p ON t.talk_id = p.talk_id
    LIMIT 5;
    '''
    result2 = pd.read_sql_query(query2, conn)
    print("\nTalks with Topics:")
    print(result2)

    # Query to get talks and their associated speakers
    query3 = '''
    SELECT t.title, t.abstract, s.name
    FROM talks t
    JOIN speakers s ON t.speaker_id = s.speaker_id
    LIMIT 5;'''
    result3 = pd.read_sql_query(query3, conn)
    print("\nTalks with Speakers:")
    print(result3)
# Out:
# Speaker GitHub Information:
#              name                      twitter  \
# 0     Alex Conway  https://twitter.com/alxcnwy
# 1  Nunudzai Mrewa                         None
# 2  Ruan Pretorius                         None
# 3   Schalk Venter                         None
# 4  Shaun De Ponte                         None
#
#                             github      username  public_repos  followers
# 0       https://github.com/alxcnwy       alxcnwy            18         44
# 1     https://github.com/JustNunuz     JustNunuz            10          4
# 2       https://github.com/ruankie       ruankie            71         19
# 3  https://github.com/schalkventer  schalkventer           171        365
# 4     https://github.com/nawtybean     nawtybean            16          5
#
# Talks with Topics:
#                                                title  \
# 0                            Applying AI with Python
# 1  Harnessing the Power of Community: Lessons fro...
# 2  It’s About Time: Time-Series Forecasting with ...
# 3   Monitoring and Evaluating LLM Apps with Langfuse
# 4  Leveraging the NLTK library for Translation: A...
#
#                                             abstract  \
# 0  Artificial Intelligence (AI) is transforming i...
# 1  Speedrunning, the art of completing video game...
# 2  Along with the rise of “AI”, data-driven decis...
# 3  Overview:\nIn the rapidly evolving landscape o...
# 4  In the field of natural language processing (N...
#
#                       assigned_topic
# 0            AI and Machine Learning
# 1       Community and Tech Education
# 2               Time Series Analysis
# 3            AI and Machine Learning
# 4  Natural Language Processing (NLP)
#
# Talks with Speakers:
#                                                title  \
# 0                            Applying AI with Python
# 1  Harnessing the Power of Community: Lessons fro...
# 2  It’s About Time: Time-Series Forecasting with ...
# 3   Monitoring and Evaluating LLM Apps with Langfuse
# 4  Leveraging the NLTK library for Translation: A...
#
#                                             abstract            name
# 0  Artificial Intelligence (AI) is transforming i...     Alex Conway
# 1  Speedrunning, the art of completing video game...  Nunudzai Mrewa
# 2  Along with the rise of “AI”, data-driven decis...  Brenden Taylor
# 3  Overview:\nIn the rapidly evolving landscape o...  Ruan Pretorius
# 4  In the field of natural language processing (N...   Alta Saunders
